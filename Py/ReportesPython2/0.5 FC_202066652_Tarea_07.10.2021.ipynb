# %% [markdown]
# # Tarea 07/10/2021
# ## Fisica Computacional
# ### Rodrigo Friend

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Porque el error de redondeo se propaga en cada iteracion, por lo que un error de redondeo mayor al de truncamiento indicaria que el error ya no converge con cada iteracion.
# 2. Cuando el valor inicial o actual no converge hacia el valor aproximado, o cuando el error de redondeo es demasiado grande.
# 3. Cuadratica
# 4. El intervalo de existencia contiene al intervalo de convergencia
# 5. b)
