# %% [markdown]
# # Física Computacional
# ## Rodrigo Friend
# ### Python
# #### Creamos un nuevo archivo y comenzamos a escribir texto con con el comando "# Texto" y el número de símbolos definirá que tan grande es el texto.

# %% [markdown]
# ### Operaciones Numéricas

# %% [markdown]
# Primero tenemos que cambiar a modo "Code"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
10 + 1
# Out:
# 11

# %%
3 / 2
# Out:
# 1.5

# %% [markdown]
# Para forzar un resultado entero usamos "//"

# %%
3 // 2
# Out:
# 1

# %% [markdown]
# Se pueden realizar operaciones con números complejos y variables

# %%
(2+3j) + (1-4j)/(1+4j)
# Out:
# (1.1176470588235294+2.5294117647058822j)

# %% [markdown]
# Para hacer elevar un número a una potencias se usa "**"

# %%
(2j)**(2)
# Out:
# (-4+0j)

# %%
9**(1/2)
# Out:
# 3.0

# %% [markdown]
# Para hallar el módulo de un complejo usamos "abs"

# %%
abs(1-3j)
# Out:
# 3.1622776601683795

# %%
abs(-3)
# Out:
# 3

# %% [markdown]
# Los siguientes comandos nos ayudan a transformar números, y salidas de otros comandos

# %%
round(_22)
# Out:
# 3

# %%
int(_22)
# Out:
# 3

# %%
complex(_22)
# Out:
# (3.1622776601683795+0j)

# %%
float(_28)
# Out:
# 3.0

# %%
float(_22)
# Out:
# 3.1622776601683795

# %% [raw]
# Otras funciones útiles

# %%
max(0, -2, 3, 1)
# Out:
# 3

# %%
min(0, -2, 3, 1)
# Out:
# -2

# %% [markdown]
# ### Asignación y operadores de comparación

# %%
a = 3 + 4j
b = -3 -4j

# %%
abs(a)
# Out:
# 5.0

# %%
a - b
# Out:
# (6+8j)

# %%
c = a*b
c
# Out:
# (7-24j)

# %%
x,y = 4,5
x,y
# Out:
# (4, 5)

# %%
(y**2 - x**2)**(1/2)
# Out:
# 3.0

# %% [markdown]
# Operadores de comparación

# %%
print(x == y)
# Out:
# False

# %%
print(x != y)
# Out:
# True

# %%
print(x >= y)
# Out:
# False

# %%
print(x < y)
# Out:
# True

# %% [markdown]
# #### Listas y Tuplas

# %%
lista = [1, 2, 3, 4, 5]
tupla = (1, 2, 3, 4, 5)
print(lista == tupla)
# Out:
# False

# %%
5 in(lista)
# Out:
# True

# %%
6 in(tupla)
# Out:
# False

# %%
len(lista) # Nos dice la cantidad de elementos
# Out:
# 5
